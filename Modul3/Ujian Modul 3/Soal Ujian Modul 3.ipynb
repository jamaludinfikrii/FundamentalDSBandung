# %% [markdown]
# ## 1. Import Libraries (pandas,numpy,matplotlib.pyplot,seaborn) and set %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('creditcard.csv')

# %% [markdown]
# ## 2. Import Data creditcard.csv and show the top 5 data

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %% [markdown]
# ## 3. Show the info of the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %% [markdown]
# ## 4. Show the describe of the dataframe

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %% [markdown]
# ## 5. Show info table of the DF like this

# %%
# Out:
#    dataFeatures dataType  null  nullPct  unique  \
# 0          Time  float64     0      0.0  124592
# 1            V1  float64     0      0.0  275663
# 2            V2  float64     0      0.0  275663
# 3            V3  float64     0      0.0  275663
# 4            V4  float64     0      0.0  275663
# 5            V5  float64     0      0.0  275663
# 6            V6  float64     0      0.0  275663
# 7            V7  float64     0      0.0  275663
# 8            V8  float64     0      0.0  275663
# 9            V9  float64     0      0.0  275663
# 10          V10  float64     0      0.0  275663
# 11          V11  float64     0      0.0  275663
# 12          V12  float64     0      0.0  275663
# 13          V13  float64     0      0.0  275663
# 14          V14  float64     0      0.0  275663
# 15          V15  float64     0      0.0  275663
# 16          V16  float64     0      0.0  275663
# 17          V17  float64     0      0.0  275663
# ...

# %% [markdown]
# ## 6. Do Standard Scaler for all variable except the target

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
data_scaled = scaler.fit_transform(df.drop('Class',axis=1))

# %%
x_scaled_df = pd.DataFrame(data_scaled,columns=df.columns[:-1])
x_scaled_df['Class'] = df['Class']

# %%
x_scaled_df.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068
# 1 -1.996583  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820
# 2 -1.996562 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454
# 3 -1.996562 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150
# 4 -1.996541 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999
#
#          V7        V8        V9  ...         V21       V22       V23  \
# 0  0.193679  0.082637  0.331128  ...   -0.024923  0.382854 -0.176911
# 1 -0.063700  0.071253 -0.232494  ...   -0.307377 -0.880077  0.162201
# 2  0.639776  0.207373 -1.378675  ...    0.337632  1.063358  1.456320
# 3  0.192071  0.316018 -1.262503  ...   -0.147443  0.007267 -0.304777
# 4  0.479302 -0.226510  0.744326  ...   -0.012839  1.100011 -0.220123
#
#         V24       V25       V26       V27       V28    Amount  Class
# ...

# %%
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068
# 1 -1.996583  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820
# 2 -1.996562 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454
# 3 -1.996562 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150
# 4 -1.996541 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999
#
#          V7        V8        V9  ...         V21       V22       V23  \
# 0  0.193679  0.082637  0.331128  ...   -0.024923  0.382854 -0.176911
# 1 -0.063700  0.071253 -0.232494  ...   -0.307377 -0.880077  0.162201
# 2  0.639776  0.207373 -1.378675  ...    0.337632  1.063358  1.456320
# 3  0.192071  0.316018 -1.262503  ...   -0.147443  0.007267 -0.304777
# 4  0.479302 -0.226510  0.744326  ...   -0.012839  1.100011 -0.220123
#
#         V24       V25       V26       V27       V28    Amount  Class
# ...

# %% [markdown]
# ## 7. Do PCA for the features to make it only 10 features remaining

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=10)

# %%
x_pca = pca.fit_transform(x_scaled_df.drop('Class',axis=1))

# %%
col = []
for i in range(1,11):
    col.append('PC ' + str(i))

# %%
x_pca_df = pd.DataFrame(x_pca,columns=['PC ' + str(i) for i in range(1,11)])

# %%
x_pca_df.head()
# Out:
#        PC 1      PC 2      PC 3      PC 4      PC 5      PC 6      PC 7  \
# 0  0.410359 -2.596403 -0.069568 -0.656360  0.360017 -0.621263 -0.510502
# 1 -0.389706 -2.037914 -0.070777 -0.680517 -0.125208 -0.184774  0.224285
# 2  1.922325 -2.528005 -0.875797 -1.043778 -0.122752 -3.701223  0.642357
# 3  0.378630 -1.697892 -1.028064  0.036507  2.206106 -1.133336  0.501910
# 4 -0.008775 -1.613759  0.318163  0.628852  0.296698  0.494958  0.347333
#
#        PC 8      PC 9     PC 10
# 0 -0.167296 -0.088776 -0.337052
# 1 -0.287226 -0.404158 -0.262511
# 2  1.002898 -1.144436 -0.356851
# 3  0.875057  0.543060  0.109150
# 4  0.525707 -0.239578  0.232817

# %% [markdown]
# #### and go make the data dataframe results of the PCA like below

# %%
# Out:
#        PC 1      PC 2      PC 3      PC 4      PC 5      PC 6      PC 7  \
# 0  0.448350 -2.565797 -0.118415  0.135285  0.316199 -0.081437 -0.126261
# 1 -0.399658 -2.058020  0.242649  0.593802  0.151454  0.427307  0.567658
# 2  1.871816 -2.591497  0.499971 -1.457879  1.466164 -0.514652  0.414906
# 3  0.301560 -1.792648  1.271196 -0.167373  1.041813 -1.909995 -0.338471
# 4 -0.017314 -1.508018  0.255944  0.745548  0.032127  0.797184 -0.370666
#
#        PC 8      PC 9     PC 10
# 0 -0.048922 -0.681680 -0.277097
# 1 -0.851002  0.369599 -0.836642
# 2 -1.188528  0.911246 -0.191219
# 3  0.140701 -0.692767  0.265438
# 4 -1.105418 -0.346440  0.279571

# %% [markdown]
# ## 8. Make target series dan show it value_counts in text and seaborn countplot, and pairplot

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
sns.countplot(data=df,x='Class')

# %% [markdown]
# ### Use PCA again to make dataframe for pairplot with just 2 PC only from PCA Dataframe you just make at no. 7, and then just take 5000 sample to make the pairplot using .sample()

# %%
pca = PCA(n_components=2)
x_pca_2 =  pca.fit_transform(x_pca_df)

# %%
x_pca_2_df = pd.DataFrame(x_pca_2,columns=['PC 1','PC 2'])
x_pca_2_df['Class'] = df['Class']

# %%
sns.pairplot(x_pca_2_df.sample(n=5000),hue='Class')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %% [markdown]
# ## 9. Use K Fold (K=5,shuffle=True,random_state=42), every loop use RandomOverSampler for the training data, and then use GradientBoostingClassifier for the model

# %%
from sklearn.metrics import accuracy_score,roc_auc_score,f1_score,matthews_corrcoef,log_loss,classification_report

# %%
def all_metrics_report(X_train,X_test,y_train,y_test,model):
    predict_train = model.predict(X_train)
    predict_test = model.predict(X_test)
    predict_proba_test = model.predict_proba(X_test)
    predict_proba_train = model.predict_proba(X_train)
    train_test_score = {
        'Train Accuracy' : accuracy_score(y_train,predict_train),
        'Test Accuracy' : accuracy_score(y_test,predict_test),
        'Train ROC AUC' : roc_auc_score(y_train,predict_proba_train[:,1]),
        'Test ROC AUC' : roc_auc_score(y_test,predict_proba_test[:,1]),
        'Train F1 Score' : f1_score(y_train,predict_train),
        'Test F1 Score' : f1_score(y_test,predict_test),
        'Train Matthews Corr Coef' : matthews_corrcoef(y_train,predict_train),
        'Test Matthews Corr Coef' : matthews_corrcoef(y_test,predict_test),
        'Train Log Loss' : log_loss(y_train,predict_proba_train),
        'Test Log Loss' : log_loss(y_test,predict_proba_test),  
    }
    
    class_report_train = classification_report(y_train,predict_train)
    class_report_test = classification_report(y_test,predict_test)
    
    return train_test_score,class_report_train,class_report_test

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X_train , X_test,y_train,y_test = train_test_split(x_pca_df,df["Class"])

# %%
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
score,cf_train,cf_test = all_metrics_report(X_train,X_test,y_train,y_test,model)

# %% [markdown]
# ## 10. Print the Model Evaluation like below from the K Fold

# %%
from sklearn.model_selection import KFold
from imblearn.over_sampling import RandomOverSampler

# %%
kf = KFold(n_splits=5,shuffle=True,random_state=42)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
data_metric = []
class_report = []
for train_i,test_i in kf.split(x_pca_df,df['Class']):
    X_train,X_test,y_train,y_test = x_pca_df.iloc[train_i] , x_pca_df.iloc[test_i], 
    df['Class'].iloc[train_i] ,df['Class'].iloc[test_i]
    ros = RandomOverSampler()
    X_ros,y_ros  = ros.fit_sample(X_train,y_train)
    model = GradientBoostingClassifier()
    model.fit(X_ros,y_ros)
    score,class_train,class_test = all_metrics_report(X_ros,X_test,y_ros,y_test,model)
    data_metric.append(score)
    class_report.append([class_train,class_test])

# %%
df_metrics_score = pd.DataFrame(data_metric)[['Train Accuracy','Test Accuracy','Train ROC AUC','Test ROC AUC','Train F1 Score',
                           'Test F1 Score','Train Matthews Corr Coef','Test Matthews Corr Coef','Train Log Loss','Test Log Loss']]

# %%
# Out:
#    Train Accuracy  Test Accuracy  Train ROC AUC  Test ROC AUC  Train F1 Score  \
# 0        0.972689       0.990748       0.998744      0.977844        0.972679
# 1        0.977344       0.991538       0.998672      0.965531        0.977339
# 2        0.983636       0.991468       0.999112      0.936064        0.983635
# 3        0.981515       0.993855       0.999143      0.969050        0.981512
# 4        0.976508       0.990502       0.998291      0.976373        0.976503
#
#    Test F1 Score  Train Matthews Corr Coef  Test Matthews Corr Coef  \
# 0       0.619624                  0.946016                 0.348710
# 1       0.623649                  0.955084                 0.355863
# 2       0.616977                  0.967412                 0.332497
# 3       0.659310                  0.963313                 0.403645
# 4       0.627569                  0.953446                 0.368413
#
#    Train Log Loss  Test Log Loss
# 0        0.082534       0.077713
# ...

# %%
for col in df_metrics_score[['Train Accuracy','Test Accuracy','Train ROC AUC','Test ROC AUC']].columns:
    print('Avg ' + col + ' = ' + str(df_metrics_score[col].mean()))
# Out:
# Avg Train Accuracy = 0.9783229191782917
# Avg Test Accuracy = 0.9862784304606519
# Avg Train ROC AUC = 0.9985143272656007
# Avg Test ROC AUC = 0.9652055988180062

# %%
# Out:
# Avg Accuracy Train : 0.9783382934075606
# Avg Accuracy Validation : 0.9916224002863834
# Avg ROC AUC Train : 0.9987924559737724
# Avg ROC AUC Validation : 0.9649727000766731

# %% [markdown]
# #### Training Errors Classification Reports

# %%
for item in np.array(class_report)[:,0]:
    print(item)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98    227451
#            1       0.99      0.97      0.98    227451
#
#    micro avg       0.98      0.98      0.98    454902
#    macro avg       0.98      0.98      0.98    454902
# weighted avg       0.98      0.98      0.98    454902
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98    227446
#            1       0.99      0.97      0.98    227446
#
#    micro avg       0.98      0.98      0.98    454892
#    macro avg       0.98      0.98      0.98    454892
# weighted avg       0.98      0.98      0.98    454892
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98    227449
#            1       0.99      0.98      0.98    227449
#
#    micro avg       0.98      0.98      0.98    454898
#    macro avg       0.98      0.98      0.98    454898
# ...

# %%
for item in np.array(class_report)[:,1]:
    print(item)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56864
#            1       0.10      0.89      0.19        98
#
#    micro avg       0.99      0.99      0.99     56962
#    macro avg       0.55      0.94      0.59     56962
# weighted avg       1.00      0.99      0.99     56962
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56869
#            1       0.09      0.88      0.16        93
#
#    micro avg       0.98      0.98      0.98     56962
#    macro avg       0.54      0.93      0.58     56962
# weighted avg       1.00      0.98      0.99     56962
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56866
#            1       0.09      0.79      0.17        95
#
#    micro avg       0.99      0.99      0.99     56961
#    macro avg       0.55      0.89      0.58     56961
# ...

# %%
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97    227451
#            1       0.99      0.95      0.97    227451
#
#    micro avg       0.97      0.97      0.97    454902
#    macro avg       0.97      0.97      0.97    454902
# weighted avg       0.97      0.97      0.97    454902
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98    227446
#            1       0.99      0.96      0.98    227446
#
#    micro avg       0.98      0.98      0.98    454892
#    macro avg       0.98      0.98      0.98    454892
# weighted avg       0.98      0.98      0.98    454892
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98    227449
#            1       0.99      0.98      0.98    227449
#
#    micro avg       0.98      0.98      0.98    454898
#    macro avg       0.98      0.98      0.98    454898
# ...

# %% [markdown]
# #### Validation Errors Classification Reports

# %%
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56864
#            1       0.14      0.87      0.24        98
#
#    micro avg       0.99      0.99      0.99     56962
#    macro avg       0.57      0.93      0.62     56962
# weighted avg       1.00      0.99      0.99     56962
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56869
#            1       0.15      0.87      0.25        93
#
#    micro avg       0.99      0.99      0.99     56962
#    macro avg       0.57      0.93      0.62     56962
# weighted avg       1.00      0.99      0.99     56962
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56866
#            1       0.14      0.80      0.24        95
#
#    micro avg       0.99      0.99      0.99     56961
#    macro avg       0.57      0.90      0.62     56961
# ...

# %% [markdown]
# ### Print Features Importance
